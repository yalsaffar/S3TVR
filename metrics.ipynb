# %% [markdown]
# # Data Needed

# %%
import pandas as pd
import torch
from datasets import load_dataset

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
minds_14_es = load_dataset("PolyAI/minds14", "es-ES") # for Spanish
# to download all data for multi-lingual fine-tuning uncomment following line
# minds_14 = load_dataset("PolyAI/all", "all")



# load audio sample on the fly
audio_input = minds_14_es["train"][0]["audio"]  # first decoded audio sample
intent_class = minds_14_es["train"][0]["intent_class"]  # first transcription
intent = minds_14_es["train"].features["intent_class"].names[intent_class]

df_es = pd.DataFrame(minds_14_es["train"])
df_es
# Out:
# c:\Users\spn\anaconda3\envs\capstone\Lib\site-packages\datasets\load.py:1429: FutureWarning: The repository for PolyAI/minds14 contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/PolyAI/minds14
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
#                                                   path  \
# 0    C:\Users\spn\.cache\huggingface\datasets\downl...
# 1    C:\Users\spn\.cache\huggingface\datasets\downl...
# 2    C:\Users\spn\.cache\huggingface\datasets\downl...
# 3    C:\Users\spn\.cache\huggingface\datasets\downl...
# 4    C:\Users\spn\.cache\huggingface\datasets\downl...
# ..                                                 ...
# 481  C:\Users\spn\.cache\huggingface\datasets\downl...
# 482  C:\Users\spn\.cache\huggingface\datasets\downl...
# 483  C:\Users\spn\.cache\huggingface\datasets\downl...
# 484  C:\Users\spn\.cache\huggingface\datasets\downl...
# 485  C:\Users\spn\.cache\huggingface\datasets\downl...
#
#                                                  audio  \
# 0    {'path': 'C:\Users\spn\.cache\huggingface\data...
# 1    {'path': 'C:\Users\spn\.cache\huggingface\data...
# 2    {'path': 'C:\Users\spn\.cache\huggingface\data...
# 3    {'path': 'C:\Users\spn\.cache\huggingface\data...
# 4    {'path': 'C:\Users\spn\.cache\huggingface\data...
# ..                                                 ...
# 481  {'path': 'C:\Users\spn\.cache\huggingface\data...
# 482  {'path': 'C:\Users\spn\.cache\huggingface\data...
# 483  {'path': 'C:\Users\spn\.cache\huggingface\data...
# 484  {'path': 'C:\Users\spn\.cache\huggingface\data...
# 485  {'path': 'C:\Users\spn\.cache\huggingface\data...
#
#                                          transcription  \
# 0    hola buenas a ver tengo un problema con vuestr...
# 1    la aplicación no cargue el saldo de mi nueva c...
# 2    hola tengo un problema con la aplicación no ca...
# 3    hola buena la aplicación no se carga el saldo ...
# 4    bueno pues resulta que la aplicación no se act...
# ..                                                 ...
# 481                            dinero depositar dinero
# 482  qué tengo que hacer para meter dinero en mi cu...
# 483  hola buenas mira llamaba porque quiero hacer u...
# 484                 cómo transferir dinero a la cuenta
# 485  cómo transfiero dinero a la cuenta donde puedo...
#
#                                  english_transcription  intent_class  lang_id
# 0    hello good to see I have a problem with your a...             2        5
# 1    the application does not load the balance of m...             2        5
# 2    hello I have a problem with the application do...             2        5
# 3    hello good the application does not load the b...             2        5
# 4    Well, it turns out that the application is not...             2        5
# ..                                                 ...           ...      ...
# 481                                money deposit money             7        5
# 482    what do I have to do to put money in my account             7        5
# 483  hello good look I was calling because I want t...             7        5
# 484                   how to transfer money to account             7        5
# 485  how do i transfer money to the account where i...             7        5
#
# [486 rows x 6 columns]

# %%
from datasets import load_dataset
import pandas as pd
minds_14_en = load_dataset("PolyAI/minds14", "en-US") # for French
# to download all data for multi-lingual fine-tuning uncomment following line
# minds_14 = load_dataset("PolyAI/all", "all")



# load audio sample on the fly
audio_input = minds_14_en["train"][0]["audio"]  # first decoded audio sample
intent_class = minds_14_en["train"][0]["intent_class"]  # first transcription
intent = minds_14_en["train"].features["intent_class"].names[intent_class]

df_en = pd.DataFrame(minds_14_en["train"])
df_en
# Out:
# c:\Users\spn\anaconda3\envs\capstone\Lib\site-packages\datasets\load.py:1429: FutureWarning: The repository for PolyAI/minds14 contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/PolyAI/minds14
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
#                                                   path  \
# 0    C:\Users\spn\.cache\huggingface\datasets\downl...
# 1    C:\Users\spn\.cache\huggingface\datasets\downl...
# 2    C:\Users\spn\.cache\huggingface\datasets\downl...
# 3    C:\Users\spn\.cache\huggingface\datasets\downl...
# 4    C:\Users\spn\.cache\huggingface\datasets\downl...
# ..                                                 ...
# 558  C:\Users\spn\.cache\huggingface\datasets\downl...
# 559  C:\Users\spn\.cache\huggingface\datasets\downl...
# 560  C:\Users\spn\.cache\huggingface\datasets\downl...
# 561  C:\Users\spn\.cache\huggingface\datasets\downl...
# 562  C:\Users\spn\.cache\huggingface\datasets\downl...
#
#                                                  audio  \
# 0    {'path': 'C:\Users\spn\.cache\huggingface\data...
# 1    {'path': 'C:\Users\spn\.cache\huggingface\data...
# 2    {'path': 'C:\Users\spn\.cache\huggingface\data...
# 3    {'path': 'C:\Users\spn\.cache\huggingface\data...
# 4    {'path': 'C:\Users\spn\.cache\huggingface\data...
# ..                                                 ...
# 558  {'path': 'C:\Users\spn\.cache\huggingface\data...
# 559  {'path': 'C:\Users\spn\.cache\huggingface\data...
# 560  {'path': 'C:\Users\spn\.cache\huggingface\data...
# 561  {'path': 'C:\Users\spn\.cache\huggingface\data...
# 562  {'path': 'C:\Users\spn\.cache\huggingface\data...
#
#                                          transcription  \
# 0    I would like to set up a joint account with my...
# 1    Henry County set up a joint account with my wi...
# 2    hi I'd like to set up a joint account with my ...
# 3                       how do I start a joint account
# 4          can you help me set up a joint bank account
# ..                                                 ...
# 558  hi I'm an account holder have been for 18 year...
# 559  I'm about to make my first payment on my loan ...
# 560  hi there I'm working about a business loan I w...
# 561                   hello I would like to take alone
# 562  hi I'm calling from Snyder hardware and I need...
#
#                                  english_transcription  intent_class  lang_id
# 0    I would like to set up a joint account with my...            11        4
# 1    Henry County set up a joint account with my wi...            11        4
# 2    hi I'd like to set up a joint account with my ...            11        4
# 3                       how do I start a joint account            11        4
# 4          can you help me set up a joint bank account            11        4
# ..                                                 ...           ...      ...
# 558  hi I'm an account holder have been for 18 year...             5        4
# 559  I'm about to make my first payment on my loan ...             5        4
# 560  hi there I'm working about a business loan I w...             5        4
# 561                   hello I would like to take alone             5        4
# 562  hi I'm calling from Snyder hardware and I need...             5        4
#
# [563 rows x 6 columns]

# %%
dataset_t = load_dataset("kde4", lang1="en", lang2="es")
dataset_t
# Out:
# c:\Users\spn\anaconda3\envs\capstone\Lib\site-packages\datasets\load.py:1429: FutureWarning: The repository for kde4 contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/kde4
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 218655
#     })
# })

# %%
df_t = pd.DataFrame(dataset_t['train'])
df_t['en'] = df_t['translation'].apply(lambda x: x.get('en'))
df_t['es'] = df_t['translation'].apply(lambda x: x.get('es'))
df_t = df_t.drop(columns=['translation', 'id'])
df_t
# Out:
#                                                        en  \
# 0                                             Lauri Watts
# 1                                   & Lauri. Watts. mail;
# 2                                    ROLES_OF_TRANSLATORS
# 3                                        2006-02-26 3.5.1
# 4       The Babel & konqueror; plugin gives you quick ...
# ...                                                   ...
# 218650                                         fade curve
# 218651                                     current volume
# 218652                                  volume to fade to
# 218653                          fade time in milliseconds
# 218654     Fade in or fade out with different fade curves
#
#                                                        es
# 0                                             Lauri Watts
# 1                                   & Lauri. Watts. mail;
# 2       Rafael Osuna rosuna@wol. es Traductor Miguel R...
# 3                                        2006-02-26 3.5.1
# 4       La extensión Babel de & konqueror; le permite ...
# ...                                                   ...
# 218650                           curva de desvanecimiento
# 218651                                     volumen actual
# 218652                                    volumen a bajar
# 218653          tiempo de desvanecimiento en milisegundos
# 218654  Subir o bajar con distintas curvas de desvanec...
#
# [218655 rows x 2 columns]

# %%
# reomve the rows with en shorter than 5 words
df_t = df_t[df_t['en'].apply(lambda x: len(x.split()) > 10)]
df_t = df_t[df_t['es'].apply(lambda x: len(x.split()) > 10)]

# reomve the rows with en longer than 30 words
df_t = df_t[df_t['en'].apply(lambda x: len(x.split()) < 30)]
df_t = df_t[df_t['es'].apply(lambda x: len(x.split()) < 30)]

# make everything lower case
df_t['en'] = df_t['en'].apply(lambda x: x.lower())
df_t['es'] = df_t['es'].apply(lambda x: x.lower())
df_t = df_t.reset_index(drop=True)
df_t = df_t.head(15000)

# %% [markdown]
# # Transcription Quality
# - Audios in English and Spanish to test the models
# - Check WER, RTF of each

# %%
# english parakeet testing
from parakeet import parakeet_ctc_model, parakeet_ctc_process
model_parakeet = parakeet_ctc_model()
model_parakeet = model_parakeet.to(device)
# Out:
# parakeet-ctc-0.6b.nemo:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# [NeMo I 2024-04-02 18:56:37 nemo_logging:381] Tokenizer SentencePieceTokenizer initialized with 1024 tokens
# [NeMo W 2024-04-02 18:56:37 nemo_logging:393] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: /disk1/NVIDIA/datasets/LibriSpeech_NeMo/librivox-train-all.json
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: true
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
#     trim_silence: false
#     max_duration: 16.7
#     min_duration: 0.1
#     is_tarred: false
#     tarred_audio_filepaths: null
#     shuffle_n: 2048
#     bucketing_strategy: fully_randomized
#     bucketing_batch_size: null
#
# [NeMo W 2024-04-02 18:56:37 nemo_logging:393] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: /disk1/NVIDIA/datasets/LibriSpeech_NeMo/librivox-dev-clean.json
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: false
#     use_start_end_token: false
#     num_workers: 8
#     pin_memory: true
#
# [NeMo W 2024-04-02 18:56:37 nemo_logging:393] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
#     Test config :
#     manifest_filepath: null
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: false
#     use_start_end_token: false
#     num_workers: 8
#     pin_memory: true
# [NeMo I 2024-04-02 18:56:37 nemo_logging:381] PADDING: 0
# [NeMo W 2024-04-02 18:56:52 nemo_logging:393] `method_cfg` is deprecated and will be removed in the future. Please use `measure_cfg` instead.
# [NeMo W 2024-04-02 18:56:52 nemo_logging:393] Re-writing `measure_cfg` with the value of `method_cfg`.
# [NeMo W 2024-04-02 18:56:52 nemo_logging:393] `temperature` is deprecated and will be removed in the future. Please use `alpha` instead.
# [NeMo W 2024-04-02 18:56:52 nemo_logging:393] Re-writing `alpha` with the value of `temperature`.
# [NeMo W 2024-04-02 18:56:52 nemo_logging:393] `method_cfg` is deprecated and will be removed in the future. Please use `measure_cfg` instead.
# [NeMo W 2024-04-02 18:56:52 nemo_logging:393] Re-writing `measure_cfg` with the value of `method_cfg`.
# [NeMo W 2024-04-02 18:56:52 nemo_logging:393] `temperature` is deprecated and will be removed in the future. Please use `alpha` instead.
# [NeMo W 2024-04-02 18:56:52 nemo_logging:393] Re-writing `alpha` with the value of `temperature`.
# [NeMo I 2024-04-02 18:57:00 nemo_logging:381] Model EncDecCTCModelBPE was successfully restored from C:\Users\spn\.cache\huggingface\hub\models--nvidia--parakeet-ctc-0.6b\snapshots\097ffc5b027beabc73acb627def2d1d278e774e9\parakeet-ctc-0.6b.nemo.

# %%
import librosa
import time

# Assuming df_en is your DataFrame and it has columns 'path' and 'transcription'

# Create an empty DataFrame with the desired columns
transcriptions_df_en = pd.DataFrame(columns=['Original Transcription', 'Predicted Transcription', 'Prediction Time (s)', 'Audio Length (s)'])

for index, row in df_en.iterrows():
    

    # Get the audio path and original transcription
    path = row['path']
    original_transcription = row['transcription']

    # Measure the start time for prediction
    start_time = time.time()
    
    # Predict the transcription (modify this part based on how your function works)
    predicted_transcription = parakeet_ctc_process(model_parakeet, path)
    
    # Measure the end time and calculate prediction time
    prediction_time = time.time() - start_time

    # Get the length of the audio
    audio_length = librosa.get_duration(filename=path)

    # Append a new row to the DataFrame
    transcriptions_df_en = transcriptions_df_en.append({
        'Original Transcription': original_transcription,
        'Predicted Transcription': predicted_transcription[0],
        'Prediction Time (s)': prediction_time,
        'Audio Length (s)': audio_length
    }, ignore_index=True)
# Out:
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# ...
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:26: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\3987611297.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_en = transcriptions_df_en.append({

# %%
transcriptions_df_en
# Out:
#                                 Original Transcription  \
# 0    I would like to set up a joint account with my...
# 1    Henry County set up a joint account with my wi...
# 2    hi I'd like to set up a joint account with my ...
# 3                       how do I start a joint account
# 4          can you help me set up a joint bank account
# ..                                                 ...
# 558  hi I'm an account holder have been for 18 year...
# 559  I'm about to make my first payment on my loan ...
# 560  hi there I'm working about a business loan I w...
# 561                   hello I would like to take alone
# 562  hi I'm calling from Snyder hardware and I need...
#
#                                Predicted Transcription  Prediction Time (s)  \
# 0    i would like to set up a joint account with my...             1.430545
# 1    wondering how i would set up a joint ht with m...             0.218018
# 2    hi i'd like to set up a joint account with my ...             0.314961
# 3                       how do i start a joint account             0.230811
# 4      can now you help me set up a joint bank account             0.242274
# ..                                                 ...                  ...
# 558  hi i'm an account holder i've been for ten yea...             0.237660
# 559  so i'm about to make my first payment on my lo...             0.211899
# 560  hi there i'm ring about a business loan i woul...             0.202363
# 561  hello i would like to take a loan what type oh...             0.354725
# 562  hi i'm calling from snyder hardware and i need...             0.300840
#
#      Audio Length (s)
# 0           10.837375
# 1            6.656000
# 2           24.234625
# 3            3.242625
# 4            3.840000
# ..                ...
# 558         14.250625
# 559          6.826625
# 560          9.659500
# 561         16.532625
# 562         15.701375
#
# [563 rows x 4 columns]

# %%
# get the wer, cer, and rtf
from jiwer import wer
from jiwer import cer
from jiwer import mer
# rtf = audio_length / prediction_time
for index, row in transcriptions_df_en.iterrows():
    original_transcription = row['Original Transcription']
    predicted_transcription = row['Predicted Transcription']
    wer_score = wer(original_transcription, predicted_transcription)
    cer_score = cer(original_transcription, predicted_transcription)
    mer_score = mer(original_transcription, predicted_transcription)
    transcriptions_df_en.at[index, 'WER'] = wer_score
    transcriptions_df_en.at[index, 'CER'] = cer_score
    transcriptions_df_en.at[index, 'MER'] = mer_score
    transcriptions_df_en.at[index, 'RTF'] =  row['Prediction Time (s)'] /row['Audio Length (s)']

# %%
transcriptions_df_en
# Out:
#                                 Original Transcription  \
# 0    I would like to set up a joint account with my...
# 1    Henry County set up a joint account with my wi...
# 2    hi I'd like to set up a joint account with my ...
# 3                       how do I start a joint account
# 4          can you help me set up a joint bank account
# ..                                                 ...
# 558  hi I'm an account holder have been for 18 year...
# 559  I'm about to make my first payment on my loan ...
# 560  hi there I'm working about a business loan I w...
# 561                   hello I would like to take alone
# 562  hi I'm calling from Snyder hardware and I need...
#
#                                Predicted Transcription  Prediction Time (s)  \
# 0    i would like to set up a joint account with my...             1.430545
# 1    wondering how i would set up a joint ht with m...             0.218018
# 2    hi i'd like to set up a joint account with my ...             0.314961
# 3                       how do i start a joint account             0.230811
# 4      can now you help me set up a joint bank account             0.242274
# ..                                                 ...                  ...
# 558  hi i'm an account holder i've been for ten yea...             0.237660
# 559  so i'm about to make my first payment on my lo...             0.211899
# 560  hi there i'm ring about a business loan i woul...             0.202363
# 561  hello i would like to take a loan what type oh...             0.354725
# 562  hi i'm calling from snyder hardware and i need...             0.300840
#
#      Audio Length (s)       WER       CER       MER       RTF
# 0           10.837375  0.666667  0.629630  0.421053  0.132001
# 1            6.656000  0.600000  0.514286  0.500000  0.032755
# 2           24.234625  0.666667  0.653061  0.422535  0.012996
# 3            3.242625  0.142857  0.033333  0.142857  0.071180
# 4            3.840000  0.100000  0.093023  0.090909  0.063092
# ..                ...       ...       ...       ...       ...
# 558         14.250625  0.217391  0.087719  0.208333  0.016677
# 559          6.826625  0.166667  0.059524  0.157895  0.031040
# 560          9.659500  0.176471  0.064935  0.176471  0.020950
# 561         16.532625  5.142857  4.687500  0.878049  0.021456
# 562         15.701375  0.235294  0.121212  0.228571  0.019160
#
# [563 rows x 8 columns]

# %%
transcriptions_df_en.to_csv('transcriptions_df_en.csv', index=False)

# %%
# Spanish stt_es_model
from es_fastconformer import stt_es_model, stt_es_process

model_sst_es = stt_es_model()
model_sst_es = model_sst_es.to(device)
# Out:
# (…)tt_es_fastconformer_hybrid_large_pc.nemo:   0%|          | 0.00/459M [00:00<?, ?B/s]
# [NeMo I 2024-04-02 19:12:57 nemo_logging:381] Tokenizer SentencePieceTokenizer initialized with 1024 tokens
# [NeMo W 2024-04-02 19:13:00 nemo_logging:393] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: null
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: true
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
#     trim_silence: false
#     max_duration: 20
#     min_duration: 0.1
#     is_tarred: false
#     tarred_audio_filepaths: null
#     shuffle_n: 2048
#     bucketing_strategy: fully_randomized
#     bucketing_batch_size: null
#     is_concat: false
#     concat_sampling_technique: random
#     concat_sampling_probabilities: ''
#
# [NeMo W 2024-04-02 19:13:00 nemo_logging:393] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: null
#     sample_rate: 16000
#     batch_size: 32
#     shuffle: false
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
#     is_concat: true
#     concat_sampling_technique: random
#     concat_sampling_probabilities:
#     - 0.099
#     - 0.2771
#     - 0.5482
#     - 0.0757
#     concat_shuffle: false
#     concat_sampling_seed: 1234
#     max_duration: 20
#
# [NeMo W 2024-04-02 19:13:00 nemo_logging:393] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
#     Test config :
#     manifest_filepath: null
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: false
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
# [NeMo I 2024-04-02 19:13:00 nemo_logging:381] PADDING: 0
# c:\Users\spn\anaconda3\envs\capstone\Lib\site-packages\torch\nn\modules\rnn.py:83: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# [NeMo I 2024-04-02 19:13:03 nemo_logging:381] Using RNNT Loss : warprnnt_numba
#     Loss warprnnt_numba_kwargs: {'fastemit_lambda': 0.0, 'clamp': -1.0}
# [NeMo I 2024-04-02 19:13:04 nemo_logging:381] Model EncDecHybridRNNTCTCBPEModel was successfully restored from C:\Users\spn\.cache\huggingface\hub\models--nvidia--stt_es_fastconformer_hybrid_large_pc\snapshots\65f775445d5947d6784c3e80d9a14d859571947f\stt_es_fastconformer_hybrid_large_pc.nemo.

# %%
transcriptions_df_es = pd.DataFrame(columns=['Original Transcription', 'Predicted Transcription', 'Prediction Time (s)', 'Audio Length (s)'])

for index, row in df_es.iterrows():
    

    # Get the audio path and original transcription
    path = row['path']
    original_transcription = row['transcription']
    # Measure the start time for prediction
    start_time = time.time()
    # Predict the transcription (modify this part based on how your function works)
    predicted_transcription = stt_es_process(model_sst_es, path)
    
    # Measure the end time and calculate prediction time
    prediction_time = time.time() - start_time

    # Get the length of the audio
    audio_length = librosa.get_duration(filename=path)

    # Append a new row to the DataFrame
    transcriptions_df_es = transcriptions_df_es.append({
        'Original Transcription': original_transcription,
        'Predicted Transcription': predicted_transcription[0][0].lower(),
        'Prediction Time (s)': prediction_time,
        'Audio Length (s)': audio_length
    }, ignore_index=True)
# Out:
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# ...
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:18: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   audio_length = librosa.get_duration(filename=path)
# C:\Users\spn\AppData\Local\Temp\ipykernel_7452\2175359063.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transcriptions_df_es = transcriptions_df_es.append({

# %%
transcriptions_df_es
# Out:
#                                 Original Transcription  \
# 0    hola buenas a ver tengo un problema con vuestr...
# 1    la aplicación no cargue el saldo de mi nueva c...
# 2    hola tengo un problema con la aplicación no ca...
# 3    hola buena la aplicación no se carga el saldo ...
# 4    bueno pues resulta que la aplicación no se act...
# ..                                                 ...
# 481                            dinero depositar dinero
# 482  qué tengo que hacer para meter dinero en mi cu...
# 483  hola buenas mira llamaba porque quiero hacer u...
# 484                 cómo transferir dinero a la cuenta
# 485  cómo transfiero dinero a la cuenta donde puedo...
#
#                                Predicted Transcription  Prediction Time (s)  \
# 0    hola, buenas. a ver, tengo un problema con vue...             1.680156
# 1    la aplicación no caro que sale de mi nueva cue...             0.331356
# 2    hola, tengo un problema con la aplicación no c...             0.748244
# 3    hola buena la aplicación no se carga, la bibli...             0.674930
# 4    bueno pues resulta que la aplicación no se act...             0.744009
# ..                                                 ...                  ...
# 481  dinero? depositad? transfiero. ¿ puedo? ¿ dónd...             0.683868
# 482  ¿ qué tengo que hacer para meter dinero en mi ...             0.428337
# 483  hola, buenas, y la llamaba porque quería hacer...             0.363788
# 484           ¿ cómo te has tenido dinero a la cuenta?             0.374665
# 485  ¿ cómo transfiero dinero a la cuenta? ¿ dónde ...             0.394645
#
#      Audio Length (s)
# 0           17.066625
# 1            4.096000
# 2           15.104000
# 3           11.434625
# 4           14.506625
# ..                ...
# 481         13.312000
# 482          5.034625
# 483          4.458625
# 484          5.802625
# 485          5.290625
#
# [486 rows x 4 columns]

# %%
for index, row in transcriptions_df_es.iterrows():
    original_transcription = row['Original Transcription']
    predicted_transcription = row['Predicted Transcription']
    # make predicted_transcription lower case
    #transcriptions_df_es.at[index, 'Predicted Transcription'] = predicted_transcription
    wer_score = wer(original_transcription, predicted_transcription)
    cer_score = cer(original_transcription, predicted_transcription)
    mer_score = mer(original_transcription, predicted_transcription)
    transcriptions_df_es.at[index, 'WER'] = wer_score
    transcriptions_df_es.at[index, 'CER'] = cer_score
    transcriptions_df_es.at[index, 'MER'] = mer_score
    transcriptions_df_es.at[index, 'RTF'] =  row['Prediction Time (s)'] / row['Audio Length (s)']

# %%
transcriptions_df_es
# Out:
#                                 Original Transcription  \
# 0    hola buenas a ver tengo un problema con vuestr...
# 1    la aplicación no cargue el saldo de mi nueva c...
# 2    hola tengo un problema con la aplicación no ca...
# 3    hola buena la aplicación no se carga el saldo ...
# 4    bueno pues resulta que la aplicación no se act...
# ..                                                 ...
# 481                            dinero depositar dinero
# 482  qué tengo que hacer para meter dinero en mi cu...
# 483  hola buenas mira llamaba porque quiero hacer u...
# 484                 cómo transferir dinero a la cuenta
# 485  cómo transfiero dinero a la cuenta donde puedo...
#
#                                Predicted Transcription  Prediction Time (s)  \
# 0    hola, buenas. a ver, tengo un problema con vue...             1.680156
# 1    la aplicación no caro que sale de mi nueva cue...             0.331356
# 2    hola, tengo un problema con la aplicación no c...             0.748244
# 3    hola buena la aplicación no se carga, la bibli...             0.674930
# 4    bueno pues resulta que la aplicación no se act...             0.744009
# ..                                                 ...                  ...
# 481  dinero? depositad? transfiero. ¿ puedo? ¿ dónd...             0.683868
# 482  ¿ qué tengo que hacer para meter dinero en mi ...             0.428337
# 483  hola, buenas, y la llamaba porque quería hacer...             0.363788
# 484           ¿ cómo te has tenido dinero a la cuenta?             0.374665
# 485  ¿ cómo transfiero dinero a la cuenta? ¿ dónde ...             0.394645
#
#      Audio Length (s)       WER       CER       MER       RTF
# 0           17.066625  0.904762  0.515152  0.542857  0.098447
# 1            4.096000  0.400000  0.156863  0.400000  0.080897
# 2           15.104000  0.243243  0.077295  0.236842  0.049539
# 3           11.434625  0.516129  0.335664  0.470588  0.059025
# 4           14.506625  0.205882  0.076087  0.205882  0.051288
# ..                ...       ...       ...       ...       ...
# 481         13.312000  3.666667  2.130435  1.000000  0.051372
# 482          5.034625  0.200000  0.060000  0.181818  0.085078
# 483          4.458625  0.500000  0.132353  0.461538  0.081592
# 484          5.802625  0.833333  0.352941  0.555556  0.064568
# 485          5.290625  0.454545  0.106061  0.384615  0.074593
#
# [486 rows x 8 columns]

# %%
transcriptions_df_es.to_csv('transcriptions_df_es.csv', index=False)

# %% [markdown]
# # Translation Quality
# - Text data with translation
# - Check WER, RTF of nllb-200

# %%
from nllb import nllb, nllb_translate
nllb_model, tokenizer = nllb()
#nllb_model = nllb_model.to(device)
#tokenizer = tokenizer.to(device)

# %%
# show me 1000 random samples from the dataset of df_t
df_t = df_t.sample(1000, random_state=42)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
import time
for index, row in df_t.iterrows():
    en = row['en']
    es = row['es']  
    # Measure the start time for prediction
    start_time_es = time.time()
    predicted_es = nllb_translate(nllb_model, tokenizer, en,'spanish')
    # Measure the end time and calculate prediction time
    prediction_time_es = time.time() - start_time_es
    # Measure the start time for prediction
    start_time_en = time.time()
    predicted_en = nllb_translate(nllb_model, tokenizer, es,'english')
    # Measure the end time and calculate prediction time
    prediction_time_en = time.time() - start_time_en
    df_t.at[index, 'predicted_es'] = predicted_es
    df_t.at[index, 'predicted_en'] = predicted_en
    df_t.at[index, 'prediction_time_es'] = prediction_time_es
    df_t.at[index, 'prediction_time_en'] = prediction_time_en

# %%
df_t_copy = df_t.copy()

# %%
from jiwer import wer
from jiwer import cer
from jiwer import mer
# get the wer, cer,mer, and rtf
for index, row in df_t.iterrows():
    en = row['en']
    es = row['es']
    predicted_es = row['predicted_es']
    predicted_en = row['predicted_en']
    wer_score_es = wer(es, predicted_es)
    cer_score_es = cer(es, predicted_es)
    mer_score_es = mer(es, predicted_es)
    wer_score_en = wer(en, predicted_en)
    cer_score_en = cer(en, predicted_en)
    mer_score_en = mer(en, predicted_en)
    df_t.at[index, 'WER_es'] = wer_score_es
    df_t.at[index, 'CER_es'] = cer_score_es
    df_t.at[index, 'MER_es'] = mer_score_es
    df_t.at[index, 'WER_en'] = wer_score_en
    df_t.at[index, 'CER_en'] = cer_score_en
    df_t.at[index, 'MER_en'] = mer_score_en
    df_t.at[index, 'RTF_es'] = len(es.split()) / row['prediction_time_es']
    df_t.at[index, 'RTF_en'] = len(en.split()) / row['prediction_time_en']

# %%
df_t.to_csv('nllb_translation_metrics.csv', index=False)

# %% [markdown]
# # Overall model metrics
# - RTF of the cascaded model
# -

# %%
from nllb import nllb, nllb_translate
from TTS_utils import xtts_v2, tts_mutli_process
from parakeet import parakeet_ctc_model, parakeet_ctc_process
from es_fastconformer import stt_es_model, stt_es_process
nllb_model, tokenizer = nllb()
nllb_model = nllb_model.to(device)
tokenizer = tokenizer.to(device)

model_parakeet = parakeet_ctc_model()
model_parakeet = model_parakeet.to(device)

model_sst_es = stt_es_model()
model_sst_es = model_sst_es.to(device)

xtts = xtts_v2()
xtts = xtts.to(device)

# %%
import os
result_dir = "results"
def pipeline(dataset, target_lang, source_lang):
    for index, row in dataset.iterrows():
        path = row['path']
        start_time = time.time()
        start_time_transcription = time.time()
        path_results = os.path.join(result_dir, f"result_{index}.wav")
        if source_lang == 'english':
            transcription = parakeet_ctc_process(model_parakeet, path)
        elif source_lang == 'spanish':
            transcription = stt_es_process(model_sst_es, path)
        transcription_time = time.time - start_time_transcription
        
        start_time_translatoion = time.time()
        translatoion = nllb_translate(nllb_model, tokenizer, transcription, source_lang)
        translation_time = time.time - start_time_translatoion

        start_time_tts = time.time()
        if target_lang == 'english':
            audio = tts_mutli_process(xtts, translatoion,path, 'en', path_results)
        elif target_lang == 'spanish':
            audio = tts_mutli_process(xtts, translatoion,path, 'es', path_results)
        tts_time = time.time - start_time_tts
        end_time = time.time() - start_time

        dataset.at[index, 'audio'] = audio
        dataset.at[index, 'predicted_transcription'] = transcription
        dataset.at[index, 'predicted_translation'] = translatoion
        dataset.at[index, 'transcription_time'] = transcription_time
        dataset.at[index, 'translation_time'] = translation_time
        dataset.at[index, 'tts_time'] = tts_time
        dataset.at[index, 'total_time'] = end_time
    return dataset

# %% [markdown]
# # Voice Similairty
# - All embeddings calculated using any encoder model
# - Voice Cloned and embeddings are calculated
# - Compute the cosine similairty with zero-shot
# - Compute the cosine similarity with fine-tuned

# %%
from resemblyzer import preprocess_wav, VoiceEncoder
from pathlib import Path
import numpy as np
# I am here if I wanna come back
# Load the two audio files
def get_similarity(audio_file1, audio_file2):
    #audio_file1 = "xtts_fine_tune/old_man_segments/wavs/segment_3.wav"
    #audio_file2 = "xtts_fine_tune/old_man_segments/wavs/segment_100.wav"

    # Preprocess the audio files
    wav1 = preprocess_wav(audio_file1)
    wav2 = preprocess_wav(audio_file2)

    # Create an instance of the VoiceEncoder
    encoder = VoiceEncoder()

    # Embed the audio files
    embed1 = encoder.embed_utterance(wav1)
    embed2 = encoder.embed_utterance(wav2)

    # Compute the similarity between the embeddings
    similarity = np.inner(embed1, embed2)

    # Print the similarity
    #print("Similarity between the two audio files:", similarity)
    return similarity

# %%
#from ..models.TTS_utils import load_manual_xtts_v2, just_inference
from models.TTS_utils import load_manual_xtts_v2, just_inference
config_path = "C:/tmp/xtts_ft/run/training/GPT_XTTS_FT-April-02-2024_05+08PM-0000000/config.json"
model_path = "C:/tmp/xtts_ft/run/training/GPT_XTTS_FT-April-02-2024_05+08PM-0000000"

xtts_v2_model = load_manual_xtts_v2(config_path, model_path)
# Out:
# c:\Users\spn\anaconda3\envs\capstone\Lib\site-packages\transformers\utils\generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# c:\Users\spn\anaconda3\envs\capstone\Lib\site-packages\transformers\utils\generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# c:\Users\spn\anaconda3\envs\capstone\Lib\site-packages\transformers\utils\generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# Loading model...
# [2024-04-07 16:09:53,841] [INFO] [real_accelerator.py:191:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-07 16:09:54,628] torch.distributed.elastic.multiprocessing.redirects: [WARNING] NOTE: Redirects are currently not supported in Windows or MacOs.
# [2024-04-07 16:09:55,241] [INFO] [logging.py:96:log_dist] [Rank -1] DeepSpeed info: version=0.14.0+ce78a63, git-hash=ce78a63, git-branch=master
# [2024-04-07 16:09:55,244] [WARNING] [config_utils.py:69:_process_deprecated_field] Config parameter replace_method is deprecated. This parameter is no longer needed, please remove from your call to DeepSpeed-inference
# [2024-04-07 16:09:55,245] [WARNING] [config_utils.py:69:_process_deprecated_field] Config parameter mp_size is deprecated use tensor_parallel.tp_size instead
# [2024-04-07 16:09:55,247] [INFO] [logging.py:96:log_dist] [Rank -1] quantize_bits = 8 mlp_extra_grouping = False, quantize_groups = 1
# [2024-04-07 16:09:55,781] [INFO] [logging.py:96:log_dist] [Rank -1] DeepSpeed-Inference config: {'layer_id': 0, 'hidden_size': 1024, 'intermediate_size': 4096, 'heads': 16, 'num_hidden_layers': -1, 'dtype': torch.float32, 'pre_layer_norm': True, 'norm_type': <NormType.LayerNorm: 1>, 'local_rank': -1, 'stochastic_mode': False, 'epsilon': 1e-05, 'mp_size': 1, 'scale_attention': True, 'triangular_masking': True, 'local_attention': False, 'window_size': 1, 'rotary_dim': -1, 'rotate_half': False, 'rotate_every_two': True, 'return_tuple': True, 'mlp_after_attn': True, 'mlp_act_func_type': <ActivationFuncType.GELU: 1>, 'specialized_mode': False, 'training_mp_size': 1, 'bigscience_bloom': False, 'max_out_tokens': 1024, 'min_out_tokens': 1, 'scale_attn_by_inverse_layer_idx': False, 'enable_qkv_quantization': False, 'use_mup': False, 'return_single_tuple': False, 'set_empty_params': False, 'transposed_mode': False, 'use_triton': False, 'triton_autotune': False, 'num_kv': -1, 'rope_theta': 10000}
# c:\Users\spn\anaconda3\envs\capstone\Lib\site-packages\transformers\utils\generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(

# %%
#just_inference(xtts_v2_model,"here.wav", "metrics/originals_en", "hello world", "en", 0)

# %%
result_dir = "metrics/originals_en"
import os
import time
for index, row in df_en.iterrows():
    path_results = os.path.join(result_dir, f"result_{index}.wav")

    path = row['path']
    # start_time = time.time()
    audio, end_time = just_inference(xtts_v2_model,path, path_results, row['transcription'], 'en', index)
    # end_time = time.time() - start_time
    #predicted_embeddings = get_audio_embeddings(pyannote_model, path_results)
    #original_embeddings = get_audio_embeddings(pyannote_model, path)
    similarity = get_similarity(path, path_results)
    df_en.at[index, 'similarity'] = similarity
    df_en.at[index, 'tts_time'] = end_time
# Out:
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 2.5821287631988525
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 15616
# Inference finished
# Loaded the voice encoder model on cuda in 0.03 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7429003715515137
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 6912
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8057212829589844
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 17920
# Received chunk 18 of audio length 17920
# Received chunk 19 of audio length 5376
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.857499599456787
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 14592
# Inference finished
# Loaded the voice encoder model on cuda in 0.03 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7790725231170654
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7885463237762451
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.03 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.743215560913086
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 11264
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.775298833847046
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 11264
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7610676288604736
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 2048
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.799299955368042
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8135485649108887
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.761864185333252
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 14336
# Inference finished
# Loaded the voice encoder model on cuda in 0.03 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8136649131774902
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 13312
# Inference finished
# Loaded the voice encoder model on cuda in 0.03 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.803016185760498
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 11264
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7547016143798828
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 14592
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7758018970489502
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 8960
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7539892196655273
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 6912
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8155972957611084
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 4608
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7211394309997559
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 8960
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7283177375793457
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 7680
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7071268558502197
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 2304
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6183080673217773
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7978088855743408
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 6656
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.811835765838623
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.5991482734680176
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 14592
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7984821796417236
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 5632
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7507836818695068
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 3584
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7575931549072266
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 2304
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8287510871887207
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 17920
# Received chunk 18 of audio length 17920
# Received chunk 19 of audio length 16640
# Received chunk 20 of audio length 7680
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8104586601257324
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 7936
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7489042282104492
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8067476749420166
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 15616
# Inference finished
# Loaded the voice encoder model on cuda in 0.03 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6373274326324463
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7821717262268066
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 4352
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7876174449920654
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 13568
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8278658390045166
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7119309902191162
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.923525094985962
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 2304
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7679016590118408
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7554669380187988
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7509241104125977
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 5632
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.638289213180542
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 6912
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7648041248321533
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 3584
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.780141830444336
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 14592
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.5944619178771973
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8017265796661377
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7769279479980469
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 2304
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6950507164001465
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 5632
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7829744815826416
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 11264
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6041285991668701
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 8960
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.819650650024414
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7835588455200195
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 6656
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6100714206695557
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 11264
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.63690185546875
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 6656
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7729480266571045
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 2048
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7359564304351807
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 8960
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.5962514877319336
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 14336
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6223022937774658
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 4352
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7735638618469238
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 7680
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6055333614349365
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6481337547302246
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 4352
# Inference finished
# Loaded the voice encoder model on cuda in 0.08 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7336268424987793
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 5632
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.762937068939209
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7780508995056152
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 14592
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.5993034839630127
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.789475679397583
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6326026916503906
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.04 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.585230827331543
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7846639156341553
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6895999908447266
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.782116413116455
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 5632
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7165732383728027
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.594440221786499
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 7936
# Inference finished
# Loaded the voice encoder model on cuda in 0.03 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8765180110931396
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7882773876190186
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 13312
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.592029333114624
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6060311794281006
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7851746082305908
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 11264
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.612968921661377
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.787839651107788
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7811279296875
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 8960
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7752866744995117
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 7936
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6009182929992676
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 15616
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.5925226211547852
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6183454990386963
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 11264
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.800356149673462
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 15616
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7926373481750488
# Received chunk 1 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.783106803894043
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 14336
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.5999736785888672
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7946794033050537
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 7680
# Inference finished
# Loaded the voice encoder model on cuda in 0.03 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.691309928894043
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 1280
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8481833934783936
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 13312
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6401424407958984
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 6656
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7597541809082031
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 5632
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.838860034942627
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 11264
# Inference finished
# Loaded the voice encoder model on cuda in 0.03 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.827054500579834
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 5632
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.2850122451782227
# Received chunk 1 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6239025592803955
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 2304
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7828729152679443
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 7680
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7578637599945068
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 1280
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6104538440704346
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 4608
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.673949956893921
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 4352
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.5975978374481201
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 2048
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.788907766342163
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 16640
# Inference finished
# Loaded the voice encoder model on cuda in 0.03 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6009190082550049
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 4608
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8604578971862793
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6770756244659424
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 14592
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.629060983657837
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6275677680969238
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 2304
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7252068519592285
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 14592
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.83589768409729
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 17920
# Received chunk 18 of audio length 17920
# Received chunk 19 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.03 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.5999574661254883
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 4352
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.5900356769561768
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.5929584503173828
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6671028137207031
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7874464988708496
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.613036870956421
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 15616
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6119844913482666
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 13568
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.888068437576294
# Received chunk 1 of audio length 16640
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.5975475311279297
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6198675632476807
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 3584
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6175432205200195
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 7680
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.607469081878662
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7489564418792725
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 8960
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# ...
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 4608
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5929219722747803
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 13312
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.6321566104888916
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5870211124420166
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 8960
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.6704013347625732
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 5632
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.7080192565917969
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 7680
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5413362979888916
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 6912
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.6854140758514404
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5679922103881836
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5690362453460693
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 14592
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5603673458099365
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.7320950031280518
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 2304
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.7072820663452148
# Received chunk 1 of audio length 8960
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5995550155639648
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 16640
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.7283499240875244
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.6666860580444336
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5498425960540771
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 17920
# Received chunk 18 of audio length 17920
# Received chunk 19 of audio length 16640
# Received chunk 20 of audio length 17920
# Received chunk 21 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.6931881904602051
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.6491546630859375
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 6656
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.6830458641052246
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 14336
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5706782341003418
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 6656
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.6459908485412598
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5473709106445312
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5829715728759766
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 15616
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.6086544990539551
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 15616
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5843138694763184
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5182859897613525
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 8960
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.6175675392150879
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5513553619384766
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 7936
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5076534748077393
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 11264
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5379223823547363
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5406341552734375
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 16640
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.7208924293518066
# Received chunk 1 of audio length 13312
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5622918605804443
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 13312
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.562485933303833
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 16640
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5402088165283203
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5561137199401855
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 6656
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.6659729480743408
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 11008
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.6454408168792725
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.6586408615112305
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 6656
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.

# %%
df_en
# Out:
#                                                   path  \
# 0    C:\Users\spn\.cache\huggingface\datasets\downl...
# 1    C:\Users\spn\.cache\huggingface\datasets\downl...
# 2    C:\Users\spn\.cache\huggingface\datasets\downl...
# 3    C:\Users\spn\.cache\huggingface\datasets\downl...
# 4    C:\Users\spn\.cache\huggingface\datasets\downl...
# ..                                                 ...
# 558  C:\Users\spn\.cache\huggingface\datasets\downl...
# 559  C:\Users\spn\.cache\huggingface\datasets\downl...
# 560  C:\Users\spn\.cache\huggingface\datasets\downl...
# 561  C:\Users\spn\.cache\huggingface\datasets\downl...
# 562  C:\Users\spn\.cache\huggingface\datasets\downl...
#
#                                                  audio  \
# 0    {'path': 'C:\Users\spn\.cache\huggingface\data...
# 1    {'path': 'C:\Users\spn\.cache\huggingface\data...
# 2    {'path': 'C:\Users\spn\.cache\huggingface\data...
# 3    {'path': 'C:\Users\spn\.cache\huggingface\data...
# 4    {'path': 'C:\Users\spn\.cache\huggingface\data...
# ..                                                 ...
# 558  {'path': 'C:\Users\spn\.cache\huggingface\data...
# 559  {'path': 'C:\Users\spn\.cache\huggingface\data...
# 560  {'path': 'C:\Users\spn\.cache\huggingface\data...
# 561  {'path': 'C:\Users\spn\.cache\huggingface\data...
# 562  {'path': 'C:\Users\spn\.cache\huggingface\data...
#
#                                          transcription  \
# 0    I would like to set up a joint account with my...
# 1    Henry County set up a joint account with my wi...
# 2    hi I'd like to set up a joint account with my ...
# 3                       how do I start a joint account
# 4          can you help me set up a joint bank account
# ..                                                 ...
# 558  hi I'm an account holder have been for 18 year...
# 559  I'm about to make my first payment on my loan ...
# 560  hi there I'm working about a business loan I w...
# 561                   hello I would like to take alone
# 562  hi I'm calling from Snyder hardware and I need...
#
#                                  english_transcription  intent_class  lang_id  \
# 0    I would like to set up a joint account with my...            11        4
# 1    Henry County set up a joint account with my wi...            11        4
# 2    hi I'd like to set up a joint account with my ...            11        4
# 3                       how do I start a joint account            11        4
# 4          can you help me set up a joint bank account            11        4
# ..                                                 ...           ...      ...
# 558  hi I'm an account holder have been for 18 year...             5        4
# 559  I'm about to make my first payment on my loan ...             5        4
# 560  hi there I'm working about a business loan I w...             5        4
# 561                   hello I would like to take alone             5        4
# 562  hi I'm calling from Snyder hardware and I need...             5        4
#
#      similarity  tts_time
# 0      0.855385  2.582129
# 1      0.884246  1.742900
# 2      0.897821  1.805721
# 3      0.767775  1.857500
# 4      0.798360  1.779073
# ..          ...       ...
# 558    0.841524  0.540209
# 559    0.816164  0.556114
# 560    0.853868  0.665973
# 561    0.805255  0.645441
# 562    0.926210  0.658641
#
# [563 rows x 8 columns]

# %%
df_en.to_csv('tts_metrics_en.csv', index=False)

# %%
import os
result_dir = "metrics/originals_es"

for index, row in df_es.iterrows():
    path_results = os.path.join(result_dir, f"result_{index}.wav")

    path = row['path']
    # start_time = time.time()
    audio, end_time = just_inference(xtts_v2_model,path, path_results, row['transcription'], 'es', index)
    # end_time = time.time() - start_time
    #predicted_embeddings = get_audio_embeddings(pyannote_model, path_results)
    #original_embeddings = get_audio_embeddings(pyannote_model, path)
    similarity = get_similarity(path, path_results)
    df_es.at[index, 'similarity'] = similarity
    df_es.at[index, 'tts_time'] = end_time
# Out:
# Inference...
# c:\Users\spn\anaconda3\envs\capstone\Lib\site-packages\TTS\tts\layers\xtts\stream_generator.py:138: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# Received chunk 0 of audio length 15616
# Time to first chunck: 4.632011651992798
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 14336
# Inference finished
# Loaded the voice encoder model on cuda in 0.03 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7490837574005127
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 7680
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7952008247375488
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 17920
# Received chunk 18 of audio length 17920
# Received chunk 19 of audio length 4352
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7569408416748047
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.749260663986206
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 17920
# Received chunk 18 of audio length 17920
# Received chunk 19 of audio length 16640
# Received chunk 20 of audio length 17920
# Received chunk 21 of audio length 17664
# Received chunk 22 of audio length 17920
# Received chunk 23 of audio length 16640
# Received chunk 24 of audio length 17920
# Received chunk 25 of audio length 17920
# Received chunk 26 of audio length 17664
# Received chunk 27 of audio length 17920
# Received chunk 28 of audio length 13312
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8083240985870361
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7792494297027588
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8002421855926514
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 4352
# Inference finished
# Loaded the voice encoder model on cuda in 0.03 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.789384126663208
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 14336
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7803988456726074
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 8960
# Inference finished
# Loaded the voice encoder model on cuda in 0.03 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7832880020141602
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 17920
# Received chunk 18 of audio length 17920
# Received chunk 19 of audio length 16640
# Received chunk 20 of audio length 17920
# Received chunk 21 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.03 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8351211547851562
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 7936
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7614471912384033
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 16640
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7862257957458496
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 14592
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7503321170806885
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 2048
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7663521766662598
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 14336
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7900803089141846
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 17920
# Received chunk 18 of audio length 17920
# Received chunk 19 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7371728420257568
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7646138668060303
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.639157772064209
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 7680
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7528977394104004
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 7680
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7360560894012451
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 4608
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8218564987182617
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 2304
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7414767742156982
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 6656
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6496238708496094
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7269983291625977
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 7680
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.72202730178833
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.732243299484253
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 8960
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.5609791278839111
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 11264
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7280409336090088
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 8960
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7145471572875977
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 4352
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7760603427886963
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7584245204925537
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 17920
# Received chunk 18 of audio length 14592
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7212603092193604
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 14336
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.575134038925171
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7717397212982178
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.772479772567749
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 4352
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6805176734924316
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 2048
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7713096141815186
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 17920
# Received chunk 18 of audio length 17920
# Received chunk 19 of audio length 16640
# Received chunk 20 of audio length 17920
# Received chunk 21 of audio length 17664
# Received chunk 22 of audio length 17920
# Received chunk 23 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# [!] Warning: The text length exceeds the character limit of 239 for language 'es', this might cause truncated audio.
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8401196002960205
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 17920
# Received chunk 18 of audio length 17920
# Received chunk 19 of audio length 16640
# Received chunk 20 of audio length 17920
# Received chunk 21 of audio length 17664
# Received chunk 22 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7429609298706055
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 16896
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.777371883392334
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 17920
# Received chunk 18 of audio length 17920
# Received chunk 19 of audio length 16640
# Received chunk 20 of audio length 17920
# Received chunk 21 of audio length 17664
# Received chunk 22 of audio length 17920
# Received chunk 23 of audio length 16640
# Received chunk 24 of audio length 17920
# Received chunk 25 of audio length 11008
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7226922512054443
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 2048
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.764348030090332
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 2304
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7638320922851562
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 13312
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7926521301269531
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 15616
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8560945987701416
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 17920
# Received chunk 18 of audio length 17920
# Received chunk 19 of audio length 16640
# Received chunk 20 of audio length 17920
# Received chunk 21 of audio length 17664
# Received chunk 22 of audio length 7936
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.822723150253296
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.03 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.726869821548462
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 2048
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# [!] Warning: The text length exceeds the character limit of 239 for language 'es', this might cause truncated audio.
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.765960931777954
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 17920
# Received chunk 18 of audio length 17920
# Received chunk 19 of audio length 16640
# Received chunk 20 of audio length 17920
# Received chunk 21 of audio length 17664
# Received chunk 22 of audio length 17920
# Received chunk 23 of audio length 16640
# Received chunk 24 of audio length 17920
# Received chunk 25 of audio length 17920
# Received chunk 26 of audio length 17664
# Received chunk 27 of audio length 17920
# Received chunk 28 of audio length 16640
# Received chunk 29 of audio length 17920
# Received chunk 30 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8226804733276367
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 4352
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.751847743988037
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 4608
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6902668476104736
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 13312
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8577680587768555
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 17920
# Received chunk 18 of audio length 17920
# Received chunk 19 of audio length 16640
# Received chunk 20 of audio length 17920
# Received chunk 21 of audio length 17664
# Received chunk 22 of audio length 17920
# Received chunk 23 of audio length 16640
# Received chunk 24 of audio length 17920
# Received chunk 25 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.856276512145996
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7875502109527588
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 16640
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7825403213500977
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7762415409088135
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7454533576965332
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 17920
# Received chunk 18 of audio length 17920
# Received chunk 19 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7925243377685547
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 8960
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7601230144500732
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 2304
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7448370456695557
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 6656
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.5753288269042969
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 11264
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7816836833953857
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7883617877960205
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.629356861114502
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 13568
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6226003170013428
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 6656
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.753453016281128
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.651486873626709
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 13312
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.635925531387329
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 15616
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7715320587158203
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8145759105682373
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8191514015197754
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 16896
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.794529914855957
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7765755653381348
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 7680
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.6283326148986816
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.5760104656219482
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 15616
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7460424900054932
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.733036756515503
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 8960
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8183605670928955
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 6912
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7447097301483154
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 6656
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.607419490814209
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 2048
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8194105625152588
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.8688719272613525
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7916738986968994
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 5632
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.806339979171753
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7860236167907715
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 2304
# Inference finished
# Loaded the voice encoder model on cuda in 0.02 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 1.7987780570983887
# ...
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 5376
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5854992866516113
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 4352
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5432884693145752
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 7680
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.4956092834472656
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 11264
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.4833979606628418
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.48337388038635254
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 8960
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.47876906394958496
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 17920
# Received chunk 18 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.535729169845581
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5696773529052734
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 10240
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5686798095703125
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5475001335144043
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 2304
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.639228343963623
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.6172266006469727
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 13312
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5272245407104492
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5130331516265869
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 5376
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.531872034072876
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5098326206207275
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 8960
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5066440105438232
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 16640
# Received chunk 15 of audio length 17920
# Received chunk 16 of audio length 17664
# Received chunk 17 of audio length 17920
# Received chunk 18 of audio length 17920
# Received chunk 19 of audio length 16640
# Received chunk 20 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5094003677368164
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5197310447692871
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5701708793640137
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 15616
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5203478336334229
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 4352
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.533501148223877
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 8960
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5323622226715088
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 14592
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.7453453540802002
# Received chunk 1 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5749061107635498
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 17664
# Received chunk 7 of audio length 17920
# Received chunk 8 of audio length 17920
# Received chunk 9 of audio length 16640
# Received chunk 10 of audio length 17920
# Received chunk 11 of audio length 17664
# Received chunk 12 of audio length 17920
# Received chunk 13 of audio length 17920
# Received chunk 14 of audio length 2048
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.6609189510345459
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 3328
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5339021682739258
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.637927770614624
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 12288
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.5495507717132568
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 7936
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.6322975158691406
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 9984
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.7030222415924072
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 1024
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.
# Inference...
# Received chunk 0 of audio length 15616
# Time to first chunck: 0.6383213996887207
# Received chunk 1 of audio length 17664
# Received chunk 2 of audio length 17920
# Received chunk 3 of audio length 17920
# Received chunk 4 of audio length 16640
# Received chunk 5 of audio length 17920
# Received chunk 6 of audio length 14336
# Inference finished
# Loaded the voice encoder model on cuda in 0.01 seconds.

# %%
df_es
# Out:
#                                                   path  \
# 0    C:\Users\spn\.cache\huggingface\datasets\downl...
# 1    C:\Users\spn\.cache\huggingface\datasets\downl...
# 2    C:\Users\spn\.cache\huggingface\datasets\downl...
# 3    C:\Users\spn\.cache\huggingface\datasets\downl...
# 4    C:\Users\spn\.cache\huggingface\datasets\downl...
# ..                                                 ...
# 481  C:\Users\spn\.cache\huggingface\datasets\downl...
# 482  C:\Users\spn\.cache\huggingface\datasets\downl...
# 483  C:\Users\spn\.cache\huggingface\datasets\downl...
# 484  C:\Users\spn\.cache\huggingface\datasets\downl...
# 485  C:\Users\spn\.cache\huggingface\datasets\downl...
#
#                                                  audio  \
# 0    {'path': 'C:\Users\spn\.cache\huggingface\data...
# 1    {'path': 'C:\Users\spn\.cache\huggingface\data...
# 2    {'path': 'C:\Users\spn\.cache\huggingface\data...
# 3    {'path': 'C:\Users\spn\.cache\huggingface\data...
# 4    {'path': 'C:\Users\spn\.cache\huggingface\data...
# ..                                                 ...
# 481  {'path': 'C:\Users\spn\.cache\huggingface\data...
# 482  {'path': 'C:\Users\spn\.cache\huggingface\data...
# 483  {'path': 'C:\Users\spn\.cache\huggingface\data...
# 484  {'path': 'C:\Users\spn\.cache\huggingface\data...
# 485  {'path': 'C:\Users\spn\.cache\huggingface\data...
#
#                                          transcription  \
# 0    hola buenas a ver tengo un problema con vuestr...
# 1    la aplicación no cargue el saldo de mi nueva c...
# 2    hola tengo un problema con la aplicación no ca...
# 3    hola buena la aplicación no se carga el saldo ...
# 4    bueno pues resulta que la aplicación no se act...
# ..                                                 ...
# 481                            dinero depositar dinero
# 482  qué tengo que hacer para meter dinero en mi cu...
# 483  hola buenas mira llamaba porque quiero hacer u...
# 484                 cómo transferir dinero a la cuenta
# 485  cómo transfiero dinero a la cuenta donde puedo...
#
#                                  english_transcription  intent_class  lang_id  \
# 0    hello good to see I have a problem with your a...             2        5
# 1    the application does not load the balance of m...             2        5
# 2    hello I have a problem with the application do...             2        5
# 3    hello good the application does not load the b...             2        5
# 4    Well, it turns out that the application is not...             2        5
# ..                                                 ...           ...      ...
# 481                                money deposit money             7        5
# 482    what do I have to do to put money in my account             7        5
# 483  hello good look I was calling because I want t...             7        5
# 484                   how to transfer money to account             7        5
# 485  how do i transfer money to the account where i...             7        5
#
#      similarity  tts_time
# 0      0.883123  4.632012
# 1      0.849036  1.749084
# 2      0.881310  1.795201
# 3      0.890354  1.756941
# 4      0.792980  1.749261
# ..          ...       ...
# 481    0.841506  0.637928
# 482    0.840986  0.549551
# 483    0.793373  0.632298
# 484    0.756751  0.703022
# 485    0.884965  0.638321
#
# [486 rows x 8 columns]

# %%
df_es.to_csv('metrics/tts_metrics_es.csv', index=False)

# %% [markdown]
# # Check for old man data

# %%
# I am here rn
oldman_df = pd.read_csv('../xtts_fine_tune/old_man_segments/metadata.csv', sep='|')
# reset the column names
oldman_df.columns = ['path', 'transcription', 'transcription2']
# drop the second transcription
oldman_df = oldman_df.drop(columns=['transcription2'])
# make every path full path with "xtts_fine_tune/old_man_segments/wavs/"
oldman_df['path'] = oldman_df['path'].apply(lambda x: f"xtts_fine_tune/old_man_segments/wavs/{x}")
oldman_df
# Out:
#                                                path  \
# 0    delete_later/old_man_segments/wavs/segment_100
# 1    delete_later/old_man_segments/wavs/segment_101
# 2    delete_later/old_man_segments/wavs/segment_102
# 3    delete_later/old_man_segments/wavs/segment_103
# 4    delete_later/old_man_segments/wavs/segment_104
# ..                                              ...
# 122   delete_later/old_man_segments/wavs/segment_94
# 123   delete_later/old_man_segments/wavs/segment_95
# 124   delete_later/old_man_segments/wavs/segment_96
# 125   delete_later/old_man_segments/wavs/segment_97
# 126   delete_later/old_man_segments/wavs/segment_99
#
#                                          transcription
# 0         because as i said before without your brains
# 1             without your ambition without your drive
# 2                           this world will be nothing
# 3           nothing because old people like me die off
# 4    i have been successful not tremendously succes...
# ..                                                 ...
# 122  through my life with that and you can do the s...
# 123                                  you don't have to
# 124  have a doctorate or a ph phd or a master's degree
# 125             what you have to have is determination
# 126  you have to have an inner will to get things d...
#
# [127 rows x 2 columns]

# %%
from TTS.tts.utils.speakers import SpeakerManager
# I will redo this after I make the clusters *******
config_path = "C:/tmp/xtts_ft/run/training/GPT_XTTS_FT-April-02-2024_05+08PM-0000000/config.json"
model_path = "C:/tmp/xtts_ft/run/training/GPT_XTTS_FT-April-02-2024_05+08PM-0000000"

manager = SpeakerManager(encoder_model_path=model_path, encoder_config_path=config_path, use_cuda=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 5
#       2 config_path = "C:/tmp/xtts_ft/run/training/GPT_XTTS_FT-April-02-2024_05+08PM-0000000/config.json"
#       3 model_path = "C:/tmp/xtts_ft/run/training/GPT_XTTS_FT-April-02-2024_05+08PM-0000000"
# ----> 5 manager = SpeakerManager(encoder_model_path=model_path, encoder_config_path=config_path, use_cuda=True)
#
# File c:\Users\spn\anaconda3\envs\capstone\Lib\site-packages\TTS\tts\utils\speakers.py:63, in SpeakerManager.__init__(self, data_items, d_vectors_file_path, speaker_id_file_path, encoder_model_path, encoder_config_path, use_cuda)
#      54 def __init__(
#      55     self,
#      56     data_items: List[List[Any]] = None,
#    (...)
#      61     use_cuda: bool = False,
#      62 ):
# ---> 63     super().__init__(
#      64         embedding_file_path=d_vectors_file_path,
#      65         id_file_path=speaker_id_file_path,
#      66         encoder_model_path=encoder_model_path,
#      67         encoder_config_path=encoder_config_path,
#      68         use_cuda=use_cuda,
#      69     )
#      71     if data_items:
#      72         self.set_ids_from_data(data_items, parse_key="speaker_name")
#
# File c:\Users\spn\anaconda3\envs\capstone\Lib\site-packages\TTS\tts\utils\managers.py:154, in EmbeddingManager.__init__(self, embedding_file_path, id_file_path, encoder_model_path, encoder_config_path, use_cuda)
#     151         self.load_embeddings_from_file(embedding_file_path)
#     153 if encoder_model_path and encoder_config_path:
# --> 154     self.init_encoder(encoder_model_path, encoder_config_path, use_cuda)
#
# File c:\Users\spn\anaconda3\envs\capstone\Lib\site-packages\TTS\tts\utils\managers.py:325, in EmbeddingManager.init_encoder(self, model_path, config_path, use_cuda)
#     323 self.use_cuda = use_cuda
#     324 self.encoder_config = load_config(config_path)
# --> 325 self.encoder = setup_encoder_model(self.encoder_config)
#     326 self.encoder_criterion = self.encoder.load_checkpoint(
#     327     self.encoder_config, model_path, eval=True, use_cuda=use_cuda, cache=True
#     328 )
#     329 self.encoder_ap = AudioProcessor(**self.encoder_config.audio)
#
# File c:\Users\spn\anaconda3\envs\capstone\Lib\site-packages\TTS\encoder\utils\generic_utils.py:119, in setup_encoder_model(config)
#     118 def setup_encoder_model(config: "Coqpit"):
# --> 119     if config.model_params["model_name"].lower() == "lstm":
#     120         model = LSTMSpeakerEncoder(
#     121             config.model_params["input_dim"],
#     122             config.model_params["proj_dim"],
#    (...)
#     126             audio_config=config.audio,
#     127         )
#     128     elif config.model_params["model_name"].lower() == "resnet":
#
# File c:\Users\spn\anaconda3\envs\capstone\Lib\site-packages\coqpit\coqpit.py:626, in Coqpit.__getattribute__(self, arg)
#     624 def __getattribute__(self, arg: str):  # pylint: disable=no-self-use
#     625     """Check if the mandatory field is defined when accessing it."""
# --> 626     value = super().__getattribute__(arg)
#     627     if isinstance(value, str) and value == "???":
#     628         raise AttributeError(f" [!] MISSING field {arg} must be defined.")
#
# AttributeError: 'XttsConfig' object has no attribute 'model_params'
